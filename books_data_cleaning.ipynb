# %%
import pandas as pd
import math
import numpy as np
from langdetect import detect
import re

# %%
df = pd.read_csv('Books_df.csv')

# %%
df.drop_duplicates()
# Out:
#       Unnamed: 0                                              Title  \
# 0              0              The Complete Novel of Sherlock Holmes
# 1              1  Black Holes (L) : The Reith Lectures [Paperbac...
# 2              2                                    The Kite Runner
# 3              3  Greenlights: Raucous stories and outlaw wisdom...
# 4              4  The Science of Storytelling: Why Stories Make ...
# ...          ...                                                ...
# 7923        7923  Insight Guides Poland (Travel Guide with Free ...
# 7924        7924              Lonely Planet India 19 (Travel Guide)
# 7925        7925  Eyewitness Travel Phrase Book French (EW Trave...
# 7926        7926             Lonely Planet Australia (Travel Guide)
# 7927        7927  Political Map of India Latest Map of India Wit...
#
#                     Author                Main Genre                Sub Genre  \
# ...

# %%
print(df.columns.tolist())
# Out:
# ['Unnamed: 0', 'Title', 'Author', 'Main Genre', 'Sub Genre', 'Type', 'Price', 'Rating', 'No. of People rated', 'URLs']

# %%
print(df.dtypes)
# Out:
# Unnamed: 0               int64
# Title                   object
# Author                  object
# Main Genre              object
# Sub Genre               object
# Type                    object
# Price                   object
# Rating                 float64
# No. of People rated    float64
# URLs                    object
# dtype: object

# %%
df['Price'] = df['Price'].replace('[\₹,]', '', regex=True).astype(float)

# %%
df['Type'].unique()
# Out:
# array(['Paperback', 'Kindle Edition', 'Audible Audiobook', 'Hardcover',
#        'Sheet music', 'Spiral-bound', 'Kindle Edition with Audio/Video',
#        'Mass Market Paperback', 'Flexibound', 'Puzzle',
#        'Single Issue Magazine', 'Staple Bound', 'Perfect Paperback',
#        'Board book', 'Product Bundle', 'Wall Chart', 'Rag Book',
#        'Print on Demand (Hardcover)', 'Gift', 'Poster', 'Cards',
#        'Misc. Supplies', 'Library Binding', 'Unknown Binding', 'Diary',
#        'Paperback Bunko', 'Textbook Binding', 'Card Book', 'Workbook',
#        'Stationery', 'Calendar', 'Game', 'Map'], dtype=object)

# %%
df = df[df['Type'] != 'Map']

# %%
df = df[df['Type'] != 'Game']

# %%
df = df[df['Type'] != 'Calendar']

# %%
df = df[df['Type'] != 'Stationery']

# %%
df = df[df['Type'] != 'Workbook']

# %%
df = df[df['Type'] != 'Diary']

# %%
df = df[df['Type'] != 'Misc. Supplies']

# %%
df = df[df['Type'] != 'Cards']

# %%
df = df[df['Type'] != 'Poster']

# %%
df = df[df['Type'] != 'Gift']

# %%
df = df[df['Type'] != 'Single Issue Magazine']

# %%
df = df[df['Type'] != 'Puzzle']

# %%
df = df[df['Type'] != 'Wall Chart']

# %%
df = df[df['Type'] != 'Sheet music']

# %%
df = df[df['Type'] != 'Card Book']

# %%
# display(df[df['Type'] == 'Card Book'])

# %%
df['Type'].unique()
# Out:
# array(['Paperback', 'Kindle Edition', 'Audible Audiobook', 'Hardcover',
#        'Spiral-bound', 'Kindle Edition with Audio/Video',
#        'Mass Market Paperback', 'Flexibound', 'Staple Bound',
#        'Perfect Paperback', 'Board book', 'Product Bundle', 'Rag Book',
#        'Print on Demand (Hardcover)', 'Library Binding',
#        'Unknown Binding', 'Paperback Bunko', 'Textbook Binding'],
#       dtype=object)

# %%
# def is_english(val):
#     try:
#         return detect(str(val)) == 'en'
#     except:
#         return False

# %%
# def non_English_title(row):
#     title = row['Title']
#     return not is_english(title)

# %%
df['language'] = df['Title'].apply(lambda x: detect(str(x)))

# %%
text = "The Complete Novel of Sherlock Holmes"
print(detect(text))
# Out:
# en

# %%
display(df)
# Out:
#       Unnamed: 0                                              Title  \
# 0              0              The Complete Novel of Sherlock Holmes
# 1              1  Black Holes (L) : The Reith Lectures [Paperbac...
# 2              2                                    The Kite Runner
# 3              3  Greenlights: Raucous stories and outlaw wisdom...
# 4              4  The Science of Storytelling: Why Stories Make ...
# ...          ...                                                ...
# 7922        7922         Lonely Planet Best of India (Travel Guide)
# 7923        7923  Insight Guides Poland (Travel Guide with Free ...
# 7924        7924              Lonely Planet India 19 (Travel Guide)
# 7925        7925  Eyewitness Travel Phrase Book French (EW Trave...
# 7926        7926             Lonely Planet Australia (Travel Guide)
#
#                     Author                Main Genre                Sub Genre  \
# ...

# %%
df.to_csv('cleaned_data.csv', index=False)
